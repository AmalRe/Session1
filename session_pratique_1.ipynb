# %% [markdown]
# # **Présentation des différentes étapes de la session**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1) Importer le jeu de données **Diabetes Dataset 2019.csv** dans un DataFrame data en utilisant la fonction **read_csv**

# %% [markdown]
# # 2) Afficher les informations du DataFrame obtenu ainsi que les noms des colonnes, la dimension, et les types des donnèes contenues dans chaque colonne.

# %% [markdown]
# #3) Afficher le nombre des observations nulles pour chaque colonne

# %% [markdown]
# # 4) Supprimer toutes les observations qui contiennent des valeurs manquantes

# %% [markdown]
# # 5) Vérifier si l'ensemble des données est équilibré : le nombre des sujets malades et celui des sujets sains sont ils égaux

# %% [markdown]
# # 6) Supprimer l'observation non valide

# %% [markdown]
# # 7)Créer deux nouvelles variables x et y, où x représente les caractéristiques et y correspond aux étiquettes

# %% [markdown]
# # 8) Transformer le contenu de chaque colonne catégorielle en des valeurs numériques.

# %% [markdown]
# # 9)Appliquer une transformation inverse en rassemlant les données de chaque colonne en 3 catégories

# %% [markdown]
# #10)Appliquer la méthode SMOTE pour équilibrer le nombre des données des deux classes.

# %% [markdown]
# # 11)Standardiser les données en utilisant la classe StandardScaler de la bibliothèque sklearn.

# %% [markdown]
# # 12) Sauvegarder le résultat au format csv.
